# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_img(id):
  arr = []
  with open(f"img/{id}", "r") as f:
    for line in f:
      arr.append(float(line))

  arr = np.array(arr).reshape((512, 512))
  plt.imshow(arr, "GnBu")
  # plt.imshow(arr, "Purples")

# plot_img(0)
id = 0

# %%
plot_img(id)
id += 1
